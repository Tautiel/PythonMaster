# %% [markdown]
# RISCRIVO IL CODICE E LO ,PODIFICO PER SEZIONI

# %%
import sys
import gc
import dis
import math
from decimal import Decimal, getcontext
from fractions import Fraction
from collections import ChainMap, namedtuple
from typing import List, Dict, Optional, Union, Callable, TypeVar
import copy
import pdb

# %%
# Python internals come funziona davvero

# %%
import time

start = time.perf_counter()

def sezione1_python_internals():

    print("=" * 80)
    print("Sezione 1 python internals")
    print("=" * 80)

    #Object model
    print("Tutto è un oggetto")
    print("=" * 80)

    x = 50.33

    print(f"x = 5000")
    print(f"ID di x = {id(x)}")
    print(f"Tipo di x = {type(x)}")
    print(f"Valore di x = {x}")
    print(f"Size in bite = {sys.getsizeof(x)}")
    print(f"Refcount = {sys.getrefcount(x)}")

    y = x
    print(f"\n y = x Cosa succede?")
    print(f"y = x ? { y is x} stesso oggetto")
    print(f"ID di x: {id(x)}")
    print(f"ID di y: {id(y)}")
    print(f"Refount ora {sys.getrefcount(x)}")

    #Immutabili 
    print("Immutabili sono: int, str, tuple")
    a = 100
    print(f" a = 100, ID : {id(a)}")
    a = a + 30.50 # Crea nuovo oggetto
    print(f" a = a + 30.50")
    print(f" a = {a}, ID = {id(a)} nuovo oggetto")

    # Mutabile
    print(f"Mutabili sono: (list, dict, set)")
    lista1 = [1, 2, 3]
    print(f"ID lista1 : {id(lista1)}")
    lista2 = lista1
    lista2.append(20.77)
    print(f"lista1 = {lista1}, ID lista1 = {id(lista1)}")
    print(f"lista2 = {lista2}, ID lista2 = {id(lista2)}")

# %%
sezione1_python_internals()

end = time.perf_counter()

print(f"Tempo trascorso = {end - start:.4f} secondi")

# %% [markdown]
# FINE GIORNO 1

# %% [markdown]
# GIORNO 2 CONSOLIDIAMO I CONCETTI

# %%
import sys 
import gc
import math
from decimal import Decimal, getcontext
from collections import ChainMap, namedtuple
from fractions import Fraction
from typing import List, Dict, Optional, Union, Callable, TypeVar
import copy
import time
import pdb

# %%
start = time.perf_counter()

print("=" * 80)
print("SESSIONE 1 RYTHON INTERNALS COME FUNZIONA DAVVERO")
print("=" * 80)

#------------------------------------------------------------------------------------------------------
# SEZIONE PYTHONJ INTERNALS 1
#------------------------------------------------------------------------------------------------------


def prima_sezione_python_internals():
    """
    Come funziona la gestione della memoria per oggetti tipi e riferimenti
    """

    print(" = " * 20)
    print("Sezione 1")
    print(" = " * 20)

    #OBJECT MODEL

    print("\n TUTTO è UN OGGETO")
    print("=" * 40)
    x = 42 
    a = 15.5
    b = 9.9
    b = a
    y = "Omega"
    z = {}
    f = []
    r = ()
    
    # VEDIAMO A COSA CORRISPONDONO

    print(" x = 42, a = 10.5, b = 9.9, b = a, y = Omega z = {}, f = [], r = ()")
    print("Abbiamo dichiarato una serie di variabili ora vediamo a cosa corrispondono")
    print(f"Vediaamo il loro valore: x = {x}, a = {a}, b = {b}, y = {y}, z = {z},  f = {f}, r = {r}")
    print(f"Vediamo ora il tipo di apparteneza: x = {type(x)}, a = {type(a)}, b = {type(b)}, y = {type(y)}, z = {type(z)}, f = {type(f)}, r = {type(r)} ")
    print(f"Ora vdeiamo il loro ID x = {id(x)}, a = {id(a)}, b = {id(b)}, y = {id(y)}, z = {id(z)}, f = {id(f)} r = {id(r)} ")
    print(f"Ora il Refcount: {sys.getrefcount(x)}")

    # Mutabili vs Immutabili

    print("immutabili sono : int, str, tuple")
    g = 100
    print(f"g = 100, ID = {id(g)}")
    g = g + 1 # stai creando un nuovo oggetto!
    print(f" g = g + 1 ID = {id(g)} è diverso quindi hai creato un nuovo oggetto")

    print("Mutabili sono: list, dict, set")
    lista1 = [1, 2, 3]
    print(f"Controlliamo id lista 1: {id(lista1)}")
    altra_lista = lista1 # Riferiment ono ncopia
    altra_lista.append(4)
    print(f"lista1 = {lista1} ID : {id(lista1)}")
    print(f"altra_liosta = {altra_lista}, ID = {altra_lista} ")

# %%
prima_sezione_python_internals()

end = time.perf_counter()

print(f"Tempo trascorso: {end - start: .4f}")

# %% [markdown]
# FINE GIORNO 2

# %% [markdown]
# INIZIO GIORNO 3 CONSOLIDAMENTO BASI INTERNALS

# %%
import sys 
import gc
import dis
import math
from decimal import Decimal, getcontext
from fractions import Fraction
from collections import ChainMap, namedtuple
from typing import List, Dict, Optional, Union, Callable, TypeVar
import copy 
import time

# %%
start = time.perf_counter()

print("="*50)
print("SESSIONJE 1")
print("="*50)

#===========================================================
#PYTHON INTERNALS
#===========================================================

def sezione1_pèython_internals_giorno3():
    """Comprendi come python gestisce la memoria, oggetti e riferimenti
    """

    print("="*50)
    print("OBJECT MODEL PYTHON INTERNALS")
    print("="*50)

    x = 55
    print(f"x = 50")
    print(f"ID di x è pari a : {id(x)}")
    print(f"il tipo di x è : {type(x)}")
    print(f"il valore di x : {x}")
    print(f" size in bites : {sys.getsizeof(x)}")
    print(f" refcount ora : {sys.getrefcount(x)}")

    #DIMOSTRA CHE è UN RIFERIMENTO

    y = x #NON COPIA IL VALORA MA IL RIFERIMENTO
    print(f"x is y? : {x is y}")
    print(f"I due ID di riferimento : {id(x)}, {id(y)} <- SONO LO STRESSO OGGETTO")
    print(f"1refcount : {sys.getrefcount(x) - 1}")

    #mutrabili e immutabili

    print("immutabili sono : int,str,tuple")
    a = 100
    print(f" ID di a corrisponde a : {id(a)}")
    a = a -20 # abbuiamo creato un nuovo oggetto
    print(f" a = a -20")
    print(f" a = {a}, ID = {id(a)} divers oquindo abbiamo creato un nuovo oggetto!")

    #mutabili

    print(f"mutabili sono : list, dict, set")
    lista1 = [1, 2, 3]
    print(f"lista1 = [1, 2, 3], ID di lista1 = {id(lista1)}")
    lista2 = lista1 #riferimento non copia
    lista2.append(5.5)
    print(f"lista2 = lista2; liosta2.append(5.5)")
    print(f"ID di lista1 e lista 2 = {id(lista1)}, {lista2} presentano lo stesso ID")

# %%
sezione1_pèython_internals_giorno3()

# %% [markdown]
# FINE GIORNO 3
